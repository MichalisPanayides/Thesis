# %%
import ambulance_game as abg
from matplotlib.lines import Line2D
from matplotlib.patches import Patch
import matplotlib.pyplot as plt
import numpy as np

# %%
def read_file(filename="demo.csv"):    
    with open(filename, "r") as f:
        csvfile = f.read().splitlines()
        list_of_str = [row.split(",") for row in csvfile]
        times = np.array([[float(i) for i in row] for row in list_of_str])
    return times

# %% [markdown]
# ## Waiting time - Overall

# %%
all_sim_unbound_waiting_times = read_file("waiting/data/sim_unbound_waiting_times_overall.csv")

all_sim_bound_waiting_times_low = read_file("waiting/data/sim_bound_waiting_times_low_overall.csv")
all_sim_bound_waiting_times_mid = read_file("waiting/data/sim_bound_waiting_times_mid_overall.csv")
all_sim_bound_waiting_times_high = read_file("waiting/data/sim_bound_waiting_times_high_overall.csv")

all_markov_waiting_times_low = read_file("waiting/data/markov_waiting_times_low_overall.csv")
all_markov_waiting_times_mid = read_file("waiting/data/markov_waiting_times_mid_overall.csv")
all_markov_waiting_times_high = read_file("waiting/data/markov_waiting_times_high_overall.csv")

# %%
lambda_2_space = np.linspace(1, 10, 6)
all_capacity_values = (15, 30, 60)

# %%
# Waiting time both individuals
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))
for index, (ax, all_markov_times, all_bounded_sim_times) in enumerate(
    zip(
        [ax1, ax2, ax3],
        [
            all_markov_waiting_times_low,
            all_markov_waiting_times_mid,
            all_markov_waiting_times_high,
        ],
        [
            all_sim_bound_waiting_times_low,
            all_sim_bound_waiting_times_mid,
            all_sim_bound_waiting_times_high,
        ],
    )
):
    ax.violinplot(
        all_sim_unbound_waiting_times.T,
        positions=lambda_2_space,
        showmeans=True,
        widths=0.3,
    )
    ax.violinplot(
        all_bounded_sim_times.T, positions=lambda_2_space, showmeans=True, widths=0.3,
    )
    ax.plot(
        lambda_2_space, all_markov_times, color="red",
    )

    legend_elements = [
        Line2D([0], [0], color="red", lw=2, label="Finite state Markov chain"),
        Patch(facecolor="tab:blue", label="Simulation", alpha=0.6),
        Patch(facecolor="tab:orange", label="Truncated simulation", alpha=0.6),
    ]
    ax.legend(handles=legend_elements, loc="upper left")
    ax.set_title(f"$N$ = $M$ = {all_capacity_values[index]}")
    ax.set_xlabel("$\lambda_2$")
    ax.set_ylabel("Waiting time")

plt.suptitle("Truncation effect on overall waiting time")
plt.savefig("waiting_time_overall.pdf", transparent=True)

# %% [markdown]
# ## Waiting time - type 1

# %%
all_sim_unbound_waiting_times_1 = read_file("waiting/data/sim_unbound_waiting_times_type_1.csv")
all_sim_bound_waiting_times_low_1 = read_file("waiting/data/sim_bound_waiting_times_low_type_1.csv")
all_sim_bound_waiting_times_mid_1 = read_file("waiting/data/sim_bound_waiting_times_mid_type_1.csv")
all_sim_bound_waiting_times_high_1 = read_file("waiting/data/sim_bound_waiting_times_high_type_1.csv")
all_markov_waiting_times_low_1 = read_file("waiting/data/markov_waiting_times_low_type_1.csv")
all_markov_waiting_times_mid_1 = read_file("waiting/data/markov_waiting_times_mid_type_1.csv")
all_markov_waiting_times_high_1 = read_file("waiting/data/markov_waiting_times_high_type_1.csv")

# %%
lambda_2_space = np.linspace(1, 10, 6)
all_capacity_values = (15, 30, 60)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))
for index, (ax, all_markov_times, all_bounded_sim_times) in enumerate(
    zip(
        [ax1, ax2, ax3],
        [
            all_markov_waiting_times_low_1,
            all_markov_waiting_times_mid_1,
            all_markov_waiting_times_high_1,
        ],
        [
            all_sim_bound_waiting_times_low_1,
            all_sim_bound_waiting_times_mid_1,
            all_sim_bound_waiting_times_high_1,
        ],
    )
):
    ax.violinplot(
        all_sim_unbound_waiting_times_1.T,
        positions=lambda_2_space,
        showmeans=True,
        widths=0.3,
    )
    ax.violinplot(
        all_bounded_sim_times.T, positions=lambda_2_space, showmeans=True, widths=0.3,
    )
    ax.plot(
        lambda_2_space, all_markov_times, color="red",
    )

    legend_elements = [
        Line2D([0], [0], color="red", lw=2, label="Finite state Markov chain"),
        Patch(facecolor="tab:blue", label="Simulation", alpha=0.6),
        Patch(facecolor="tab:orange", label="Truncated simulation", alpha=0.6),
    ]
    ax.legend(handles=legend_elements, loc="upper left")
    ax.set_title(f"$N$ = $M$ = {all_capacity_values[index]}")
    ax.set_xlabel("$\lambda_2$")
    ax.set_ylabel("Waiting time")

plt.suptitle("Truncation effect on type 1 individuals waiting time")
plt.savefig("waiting_time_type_1.pdf", transparent=True)

# %% [markdown]
# ## Waiting time - type 2

# %%
all_sim_unbound_waiting_times_2 = read_file("waiting/data/sim_unbound_waiting_times_type_2.csv")
all_sim_bound_waiting_times_low_2 = read_file("waiting/data/sim_bound_waiting_times_low_type_2.csv")
all_sim_bound_waiting_times_mid_2 = read_file("waiting/data/sim_bound_waiting_times_mid_type_2.csv")
all_sim_bound_waiting_times_high_2 = read_file("waiting/data/sim_bound_waiting_times_high_type_2.csv")
all_markov_waiting_times_low_2 = read_file("waiting/data/markov_waiting_times_low_type_2.csv")
all_markov_waiting_times_mid_2 = read_file("waiting/data/markov_waiting_times_mid_type_2.csv")
all_markov_waiting_times_high_2 = read_file("waiting/data/markov_waiting_times_high_type_2.csv")

# %%
lambda_2_space = np.linspace(1, 10, 6)
all_capacity_values = (15, 30, 60)

# %%
# Waiting time both individuals
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))
for index, (ax, all_markov_times, all_bounded_sim_times) in enumerate(
    zip(
        [ax1, ax2, ax3],
        [
            all_markov_waiting_times_low_2,
            all_markov_waiting_times_mid_2,
            all_markov_waiting_times_high_2,
        ],
        [
            all_sim_bound_waiting_times_low_2,
            all_sim_bound_waiting_times_mid_2,
            all_sim_bound_waiting_times_high_2,
        ],
    )
):
    ax.violinplot(
        all_sim_unbound_waiting_times_2.T,
        positions=lambda_2_space,
        showmeans=True,
        widths=0.3,
    )
    ax.violinplot(
        all_bounded_sim_times.T, positions=lambda_2_space, showmeans=True, widths=0.3,
    )
    ax.plot(
        lambda_2_space, all_markov_times, color="red",
    )

    legend_elements = [
        Line2D([0], [0], color="red", lw=2, label="Finite state Markov chain"),
        Patch(facecolor="tab:blue", label="Simulation", alpha=0.6),
        Patch(facecolor="tab:orange", label="Truncated simulation", alpha=0.6),
    ]
    ax.legend(handles=legend_elements, loc="upper left")
    ax.set_title(f"$N$ = $M$ = {all_capacity_values[index]}")
    ax.set_xlabel("$\lambda_2$")
    ax.set_ylabel("Waiting time")

plt.suptitle("Truncation effect on type 2 indviduals waiting time")
plt.savefig("waiting_time_type_2.pdf", transparent=True)

# %% [markdown]
# # Blocking

# %%
all_sim_unbound_blocking_times = read_file("blocking/data/sim_unbound_blocking_times.csv")
all_sim_bound_blocking_times_low = read_file("blocking/data/sim_bound_blocking_times_low.csv")
all_sim_bound_blocking_times_mid = read_file("blocking/data/sim_bound_blocking_times_mid.csv")
all_sim_bound_blocking_times_high = read_file("blocking/data/sim_bound_blocking_times_high.csv")
all_markov_blocking_times_low = read_file("blocking/data/markov_blocking_times_low.csv")
all_markov_blocking_times_mid = read_file("blocking/data/markov_blocking_times_mid.csv")
all_markov_blocking_times_high = read_file("blocking/data/markov_blocking_times_high.csv")

# %%
lambda_2_space = np.linspace(1, 10, 6)
all_capacity_values = (15, 30, 60)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))
for index, (ax, all_markov_times, all_bounded_sim_times) in enumerate(
    zip(
        [ax1, ax2, ax3],
        [
            all_markov_blocking_times_low,
            all_markov_blocking_times_mid,
            all_markov_blocking_times_high,
        ],
        [
            all_sim_bound_blocking_times_low,
            all_sim_bound_blocking_times_mid,
            all_sim_bound_blocking_times_high,
        ],
    )
):
    ax.violinplot(
        all_sim_unbound_blocking_times.T,
        positions=lambda_2_space,
        showmeans=True,
        widths=0.3,
    )
    ax.violinplot(
        all_bounded_sim_times.T,
        positions=lambda_2_space,
        showmeans=True,
        widths=0.3,
    )
    ax.plot(
        lambda_2_space,
        all_markov_times,
        color="red",
    )

    legend_elements = [
        Line2D([0], [0], color="red", lw=2, label="Finite state Markov chain"),
        Patch(facecolor="tab:blue", label="Simulation", alpha=0.6),
        Patch(facecolor="tab:orange", label="Truncated simulation", alpha=0.6),
    ]
    ax.legend(handles=legend_elements, loc="upper left")
    ax.set_title(f"$N$ = $M$ = {all_capacity_values[index]}")
    ax.set_xlabel("$\lambda_2$")
    ax.set_ylabel("Blocking time")

plt.suptitle("Truncation effect on blocking time")
plt.savefig("blocking_time_type_2.pdf", transparent=True)

# %% [markdown]
# # Proportion - overall

# %%
all_sim_unbound_props = read_file("proportion/data/sim_unbound_props_overall.csv")

all_sim_bound_props_low = read_file("proportion/data/sim_bound_props_low_overall.csv")
all_sim_bound_props_mid = read_file("proportion/data/sim_bound_props_mid_overall.csv")
all_sim_bound_props_high = read_file("proportion/data/sim_bound_props_high_overall.csv")

all_markov_props_low = read_file("proportion/data/markov_props_low_overall.csv")
all_markov_props_mid = read_file("proportion/data/markov_props_mid_overall.csv")
all_markov_props_high = read_file("proportion/data/markov_props_high_overall.csv")

# %%
lambda_2_space = np.linspace(1, 10, 6)
all_capacity_values = (15, 30, 60)

# %%
# Waiting time both individuals
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))
for index, (ax, all_markov_times, all_bounded_sim_times) in enumerate(
    zip(
        [ax1, ax2, ax3],
        [all_markov_props_low, all_markov_props_mid, all_markov_props_high,],
        [all_sim_bound_props_low, all_sim_bound_props_mid, all_sim_bound_props_high,],
    )
):
    ax.violinplot(
        all_sim_unbound_props.T, positions=lambda_2_space, showmeans=True, widths=0.3
    )
    ax.violinplot(
        all_bounded_sim_times.T, positions=lambda_2_space, showmeans=True, widths=0.3
    )
    ax.plot(
        lambda_2_space, all_markov_times, color="red",
    )

    legend_elements = [
        Line2D([0], [0], color="red", lw=2, label="Finite state Markov chain"),
        Patch(facecolor="tab:blue", label="Simulation", alpha=0.6),
        Patch(facecolor="tab:orange", label="Truncated simulation", alpha=0.6),
    ]
    ax.legend(handles=legend_elements, loc="best")
    ax.set_title(f"$N$ = $M$ = {all_capacity_values[index]}")
    ax.set_xlabel("$\lambda_2$")
    ax.set_ylabel("% within target")

plt.suptitle("Truncation effect on proportion of individuals within target")
plt.savefig("proportion_overall.pdf", transparent=True)

# %% [markdown]
# # Proportion - type 1

# %%
all_sim_unbound_props_1 = read_file("proportion/data/sim_unbound_props_type_1.csv")

all_sim_bound_props_low_1 = read_file("proportion/data/sim_bound_props_low_type_1.csv")
all_sim_bound_props_mid_1 = read_file("proportion/data/sim_bound_props_mid_type_1.csv")
all_sim_bound_props_high_1 = read_file("proportion/data/sim_bound_props_high_type_1.csv")

all_markov_props_low_1 = read_file("proportion/data/markov_props_low_type_1.csv")
all_markov_props_mid_1 = read_file("proportion/data/markov_props_mid_type_1.csv")
all_markov_props_high_1 = read_file("proportion/data/markov_props_high_type_1.csv")

# %%
lambda_2_space = np.linspace(1, 10, 6)
all_capacity_values = (15, 30, 60)

# %%
# Waiting time both individuals
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))
for index, (ax, all_markov_times, all_bounded_sim_times) in enumerate(
    zip(
        [ax1, ax2, ax3],
        [all_markov_props_low_1, all_markov_props_mid_1, all_markov_props_high_1,],
        [all_sim_bound_props_low_1, all_sim_bound_props_mid_1, all_sim_bound_props_high_1,],
    )
):
    ax.violinplot(
        all_sim_unbound_props_1.T, positions=lambda_2_space, showmeans=True, widths=0.3
    )
    ax.violinplot(
        all_bounded_sim_times.T, positions=lambda_2_space, showmeans=True, widths=0.3
    )
    ax.plot(
        lambda_2_space, all_markov_times, color="red",
    )

    legend_elements = [
        Line2D([0], [0], color="red", lw=2, label="Finite state Markov chain"),
        Patch(facecolor="tab:blue", label="Simulation", alpha=0.6),
        Patch(facecolor="tab:orange", label="Truncated simulation", alpha=0.6),
    ]
    ax.legend(handles=legend_elements, loc="best")
    ax.set_title(f"$N$ = $M$ = {all_capacity_values[index]}")
    ax.set_xlabel("$\lambda_2$")
    ax.set_ylabel("% within target")

plt.suptitle("Truncation effect on proportion of type 1 individuals within target")
plt.savefig("proportion_type_1.pdf", transparent=True)

# %% [markdown]
# # Proportion - type 2

# %%
all_sim_unbound_props_2 = read_file("proportion/data/sim_unbound_props_type_2.csv")

all_sim_bound_props_low_2 = read_file("proportion/data/sim_bound_props_low_type_2.csv")
all_sim_bound_props_mid_2 = read_file("proportion/data/sim_bound_props_mid_type_2.csv")
all_sim_bound_props_high_2 = read_file("proportion/data/sim_bound_props_high_type_2.csv")

all_markov_props_low_2 = read_file("proportion/data/markov_props_low_type_2.csv")
all_markov_props_mid_2 = read_file("proportion/data/markov_props_mid_type_2.csv")
all_markov_props_high_2 = read_file("proportion/data/markov_props_high_type_2.csv")

# %%
lambda_2_space = np.linspace(1, 10, 6)
all_capacity_values = (15, 30, 60)

# %%
# Waiting time both individuals
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))
for index, (ax, all_markov_times, all_bounded_sim_times) in enumerate(
    zip(
        [ax1, ax2, ax3],
        [all_markov_props_low_2, all_markov_props_mid_2, all_markov_props_high_2,],
        [all_sim_bound_props_low_2, all_sim_bound_props_mid_2, all_sim_bound_props_high_2,],
    )
):
    ax.violinplot(
        all_sim_unbound_props_2.T, positions=lambda_2_space, showmeans=True, widths=0.3
    )
    ax.violinplot(
        all_bounded_sim_times.T, positions=lambda_2_space, showmeans=True, widths=0.3
    )
    ax.plot(
        lambda_2_space, all_markov_times, color="red",
    )

    legend_elements = [
        Line2D([0], [0], color="red", lw=2, label="Finite state Markov chain"),
        Patch(facecolor="tab:blue", label="Simulation", alpha=0.6),
        Patch(facecolor="tab:orange", label="Truncated simulation", alpha=0.6),
    ]
    ax.legend(handles=legend_elements, loc="best")
    ax.set_title(f"$N$ = $M$ = {all_capacity_values[index]}")
    ax.set_xlabel("$\lambda_2$")
    ax.set_ylabel("% within target")

plt.suptitle("Truncation effect on proportion of type 2 individuals within target")
plt.savefig("proportion_type_2.pdf", transparent=True)
